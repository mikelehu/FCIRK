# %% [markdown]
# <h1> Analisys: N16-BodyProblem (efficiency)</h1>

# %% [markdown]
# <ul id="top">
#   <li><a href="#Initializations">Initializations</a></li>
#   <li><a href="#Input-statistics">Input-statistics</a></li>
#   <li><a href="#Integration-Parameters">Integration-Parameters </a></li>
#   <li><a href="#Numerical-Integrations-Threads1">Numerical-Integrations-Threads1</a></li>
#       <ul>
#         <li><a href="#Data-Threads1">Data-Threads1</a></li>
#         <li><a href="#Graphics-Threads1">Graphics-Threads1</a></li>
#       </ul>
#   <li><a href="#Numerical-Integrations-Thread2">Numerical-Integrations-Thread2</a></li>
#         <ul>
#         <li><a href="#Data-Threads2">Data-Threads2</a></li>
#         <li><a href="#Graphics-Threads2">Graphics-Threads2</a></li>
#       </ul>
# </ul>

# %% [markdown]
# <h2 id="Initializations">Initializations</h2>

# %%
using NBInclude;
using Dates;
using Plots;
using DelimitedFiles;

# %%
MYPATH="../../../Code/Julia/"
@nbinclude(string(MYPATH,"NBodyProblem.ipynb"));
@nbinclude(string(MYPATH,"C-Interfaces.ipynb"));
@nbinclude(string(MYPATH,"AuxiliarFunctions.ipynb"));

# %%
#Filenames
#Input

# Eficiency statistics (Threads=1)
StatcsT11="./Data/StacsT11.txt"
StatcsT12="./Data/StacsT12.txt"
StatcsT13="./Data/StacsT13.txt";
StatcsT14="./Data/StacsT14.txt";
# Eficiency statistics (Threads=2)
StatcsT21="./Data/StacsT21.txt"
StatcsT22="./Data/StacsT22.txt"
StatcsT23="./Data/StacsT23.txt";
StatcsT24="./Data/StacsT24.txt";
# Eficiency statistics (Threads=4)
StatcsT41="./Data/StacsT41.txt"
StatcsT42="./Data/StacsT42.txt"
StatcsT43="./Data/StacsT43.txt";
StatcsT44="./Data/StacsT44.txt";

# %%
#Plot parameters
# Title
MyTitle="N16-Body Problem"
# Energy plots
Eaxa=-26
Eaxb=-10
# Position and velocity plots
axisya=-26
axisyb=-12;

# %% [markdown]
# <a href="#top">Back to the top</a>

# %% [markdown]
# <h2 id="Input-statistics">Input-statistics</h2>

# %%
f1=open(StatcsT11,"r");
f2=open(StatcsT12,"r");
f3=open(StatcsT13,"r");
f4=open(StatcsT14,"r");
results1=readdlm(f1)
results2=readdlm(f2)
results3=readdlm(f3)
results4=readdlm(f4)
close(f1)
close(f2)
close(f3)
close(f4)

# %%
#f1=open(StatcsT21,"r");
#f2=open(StatcsT22,"r");
f3=open(StatcsT23,"r");
f4=open(StatcsT24,"r");
#results1T2=readcsv(f1)
#results2T2=readcsv(f2)
results3T2=readdlm(f3)
results4T2=readdlm(f4)
#close(f1)
#close(f2)
close(f3)
close(f4)

# %%
#f1=open(StatcsT21,"r");
#f2=open(StatcsT22,"r");
f3=open(StatcsT43,"r");
f4=open(StatcsT44,"r");
#results1T2=readcsv(f1)
#results2T2=readcsv(f2)
results3T4=readdlm(f3)
results4T4=readdlm(f4)
#close(f1)
#close(f2)
close(f3)
close(f4)

# %% [markdown]
# <a href="#top">Back to the top</a>

# %% [markdown]
# <h2 id="Numerical-Integrations-Threads1">Numerical-Integrations-Threads1</h2>

# %% [markdown]
# <h3 id="Data-Threads1">Data-Threads1</h3>

# %%
nk=22*4;
nsuccess1,nsteps1,nfcn1,MaxDE1,CTime1,WTime1=Assing_results(nk,results1)    
nsuccess2,nsteps2,nfcn2,MaxDE2,CTime2,WTime2=Assing_results(nk,results2)    
nsuccess3,nsteps3,nfcn3,MaxDE3,CTime3,WTime3=Assing_results(nk,results3)    
nsuccess4,nsteps4,nfcn4,MaxDE4,CTime4,WTime4=Assing_results(nk,results4)
transpose([nsuccess1,nsuccess2,nsuccess4,nsuccess4])
# Out:
# 1×4 Transpose{Float64,Array{Float64,1}}:
#  88.0  88.0  88.0  88.0

# %% [markdown]
# <h3 id="Data-Threads1">Graphics-Threads1</h3>

# %% [markdown]
# <h4> Plot (DE/ Nfcn) </h4>

# %%
plot(nfcn1, MaxDE1,  marker = :diamond, label="ABAH1064")
#plot!(nfcn2, MaxDE2, marker = :hexagon,label="CO1035")
plot!(nfcn3, MaxDE3, marker = :circle, label="FCIRK-LQ (s=6)")
plot!(nfcn4, MaxDE4, marker = :square, label="FCIRK-LQ (s=8)")
plot!(title=string(MyTitle," (long)"),
      xlabel="Fcn(log)",
      ylabel="Energy Error(log)",
      ylims=(axisya,axisyb),
#      xlims=(0,tend),
#      yticks=[-1e-16,0,1e-16],
      ytickfont = font(10, "Courier")
)

# %%
savefig("./FiguresPost/11-Efficiency1.pdf")

# %% [markdown]
# <h4> Plot (DE/ CPU Time) </h4>

# %%
plot(CTime1, MaxDE1,  marker = :diamond,  label="ABAH1064")
#plot!(CTime2, MaxDE2, marker = :hexagon, label="CO1035")
plot!(CTime3, MaxDE3, marker = :circle, label="FCIRK-LQ (s=6)")
plot!(CTime4, MaxDE4, marker = :square,label="FCIRK-LQ (s=8)")
plot!(title="N16-Body Problem (long)",
xlabel="CPU Time(log)",
      ylabel="Energy Error(log)",
      ylims=(axisya,axisyb),
#      xlims=(0,tend),
#      yticks=[-1e-16,0,1e-16],
       xticks=[1.25,1.5,1.75,2,2.3,2.5,2.75],
      ytickfont = font(10, "Courier")
)

# %%
savefig("./FiguresPost/12-Efficiency2.pdf")

# %%
#FCIRK-S8
(CTime4[60:70],MaxDE4[60:70],nsteps4[60:70])
# Out:
# ([2.32311, 2.30945, 2.29664, 2.28092, 2.26904, 2.2562, 2.24658, 2.23675, 2.22726, 2.21461, 2.20244], [-21.8425, -21.0972, -20.9235, -20.8316, -19.5314, -20.3038, -18.942, -19.5615, -19.09, -18.9838, -18.5918], [222980.0, 213520.0, 204470.0, 195800.0, 187500.0, 179550.0, 171940.0, 164650.0, 157670.0, 150980.0, 144580.0])

# %%
(CTime4[61],MaxDE4[61],nsteps4[61])
# Out:
# (2.3094458120870414, -21.097239722052663, 213520.0)

# %%
t0=0
tend=1000000.
(tend-t0)/nsteps4[61]
# Out:
# 4.683402023229674

# %%
k1=63
(CTime4[k1],MaxDE4[k1],nsteps4[k1])
t0=0
tend=1000000.
(CTime4[k1],(tend-t0)/nsteps4[k1])
# Out:
# (2.2809191004974627, 5.107252298263535)

# %%
#ABAH1064
(CTime1[20:30],MaxDE1[20:30],nsteps1[20:30])
# Out:
# ([2.40506, 2.3871, 2.36818, 2.34998, 2.33209, 2.31374, 2.29552, 2.27698, 2.25747, 2.2394, 2.21939], [-19.1096, -19.6689, -19.5263, -19.3686, -19.7018, -19.5111, -19.2143, -19.4897, -19.2141, -19.2142, -19.3836], [1.68179e6, 1.61049e6, 1.54221e6, 1.47683e6, 1.41421e6, 1.35426e6, 1.29684e6, 1.24186e6, 1.18921e6, 1.13879e6, 1.09051e6])

# %%
(CTime1[26],MaxDE1[26],nsteps1[26])
# Out:
# (2.2955227400259948, -19.214252282854257, 1.29684e6)

# %%
t0=0
tend=1000000.
(tend-t0)/nsteps1[26]
# Out:
# 0.7711051478979674

# %%
k2=26
(CTime1[k2],MaxDE1[k2],nsteps1[k2])
t0=0
tend=1000000.
(CTime1[k2],(tend-t0)/nsteps1[k2])
# Out:
# (2.2955227400259948, 0.7711051478979674)

# %%
plot(CTime1[k2:k2], MaxDE1[k2:k2],  marker = :diamond,  label="ABAH1064")
plot!(CTime4[k1:k1], MaxDE4[k1:k1], marker = :square,label="FCIRK-LQ (s=8)")
plot!(title="N16-Body Problem (long)",
xlabel="CPU Time(log)",
      ylabel="Energy Error(log)",
      ylims=(axisya,axisyb),
#      xlims=(0,tend),
#      yticks=[-1e-16,0,1e-16],
       xticks=[2,2.2],
      ytickfont = font(10, "Courier")
)

# %% [markdown]
# <h3> Irudiak (DE/ WALL Time) </h3>

# %%
plot(WTime1, MaxDE1, marker = :diamond,  label="ABAH1064")
#plot!(WTime2, MaxDE2, marker = :hexagon, label="CO1035")
plot!(WTime3, MaxDE3,  marker = :circle, label="FCIRK-LQ (s=6)")
plot!(WTime4, MaxDE4, marker = :square,label="FCIRK-LQ (s=8)")
plot!(title=string(MyTitle," (long)"),
xlabel="WALL Time(log)",
      ylabel="Energy Error(log)",
      ylims=(axisya,axisyb),
#      xlims=(0,tend),
#      yticks=[-1e-16,0,1e-16],
      ytickfont = font(10, "Courier")
)

# %% [markdown]
# <a href="#top">Back to the top</a>

# %% [markdown]
# <h2 id="Numerical-Integrations-Threads2">Numerical-Integrations-Threads2</h2>

# %% [markdown]
# <h3 id="Data-Threads2">Data-Threads2</h3>

# %%
nsuccess3T2,nsteps3T2,nfcn3T2,MaxDE3T2,CTime3T2,WTime3T2=Assing_results(nk,results3T2)
nsuccess4T2,nsteps4T2,nfcn4T2,MaxDE4T2,CTime4T2,WTime4T2=Assing_results(nk,results4T2);
transpose([nsuccess3T2,nsuccess4T2])
# Out:
# 1×2 Transpose{Float64,Array{Float64,1}}:
#  88.0  88.0

# %% [markdown]
# <h3 id="Data-Threads2">Graphics-Threads2</h3>

# %% [markdown]
# <h4> Plot (DE/ WALL Time) </h4>

# %%
plot(WTime1, MaxDE1, marker = :diamond,   label="ABAH1064")
#plot!(WTime2, MaxDE2, marker = :diamond,  label="CO1035")
plot!(WTime3T2, MaxDE3,  marker = :circle, label="FCIRK-LQ (s=6)")
plot!(WTime4T2, MaxDE4, marker = :square, label="FCIRK-LQ (s=8)")
plot!(title=string(MyTitle," (long,threads=2)"),
xlabel="WALL Time(log)",
      ylabel="Energy Error(log)",
      ylims=(axisya,axisyb),
#      xlims=(0,tend),
#      yticks=[-1e-16,0,1e-16],
      ytickfont = font(10, "Courier")
)

# %%
savefig("./FiguresPost/13-Efficiency3.pdf")
# Out:
# SystemError: opening file "./FiguresPost/3-WallTimeT2.pdt.png": No such file or directory
#
# Stacktrace:
#  [1] #systemerror#43(::Nothing, ::Function, ::String, ::Bool) at ./error.jl:134
#  [2] systemerror at ./error.jl:134 [inlined]
#  [3] #open#309(::Nothing, ::Nothing, ::Nothing, ::Bool, ::Nothing, ::Function, ::String) at ./iostream.jl:283
#  [4] #open at ./none:0 [inlined]
#  [5] open(::String, ::String) at ./iostream.jl:339
#  [6] png(::Plots.Plot{Plots.GRBackend}, ::String) at /home/joseba/.julia/packages/Plots/oiirH/src/output.jl:7
#  [7] savefig(::Plots.Plot{Plots.GRBackend}, ::String) at /home/joseba/.julia/packages/Plots/oiirH/src/output.jl:121
#  [8] savefig(::String) at /home/joseba/.julia/packages/Plots/oiirH/src/output.jl:123
#  [9] top-level scope at In[16]:1

# %% [markdown]
# <a href="#top">Back to the top</a>

# %% [markdown]
# <h2 id="Numerical-Integrations-Threads4">Numerical-Integrations-Threads4</h2>

# %% [markdown]
# ### Data-Threads4

# %%
nsuccess3T4,nsteps3T4,nfcn3T4,MaxDE3T4,CTime3T4,WTime3T4=Assing_results(nk,results3T4)
nsuccess4T4,nsteps4T4,nfcn4T4,MaxDE4T4,CTime4T4,WTime4T4=Assing_results(nk,results4T4);
transpose([nsuccess3T4,nsuccess4T4])
# Out:
# 1×2 Transpose{Float64,Array{Float64,1}}:
#  88.0  88.0

# %% [markdown]
# <h3 id="Data-Threads3">Graphics-Threads3</h3>

# %% [markdown]
# <h4> Plot (DE/ WALL Time) </h4>

# %%
plot(WTime1, MaxDE1, marker = :diamond,   label="ABAH1064")
#plot!(WTime2, MaxDE2, marker = :diamond,  label="CO1035")
plot!(WTime3T4, MaxDE3,  marker = :circle, label="FCIRK-LQ (s=6)")
plot!(WTime4T4, MaxDE4, marker = :square, label="FCIRK-LQ (s=8)")
plot!(title=string(MyTitle," (long,threads=4)"),
xlabel="WALL Time(log)",
      ylabel="Energy Error(log)",
      ylims=(axisya,axisyb),
#      xlims=(0,tend),
#      yticks=[-1e-16,0,1e-16],
      ytickfont = font(10, "Courier")
)

# %%
savefig("./FiguresPost/14-Efficiency4.pdf")
# Out:
# SystemError: opening file "./FiguresPost/3-WallTimeT4.pdf": No such file or directory
#
# Stacktrace:
#  [1] #systemerror#43(::Nothing, ::Function, ::String, ::Bool) at ./error.jl:134
#  [2] systemerror at ./error.jl:134 [inlined]
#  [3] #open#309(::Nothing, ::Nothing, ::Nothing, ::Bool, ::Nothing, ::Function, ::String) at ./iostream.jl:283
#  [4] #open at ./none:0 [inlined]
#  [5] open(::String, ::String) at ./iostream.jl:339
#  [6] pdf(::Plots.Plot{Plots.GRBackend}, ::String) at /home/joseba/.julia/packages/Plots/oiirH/src/output.jl:24
#  [7] savefig(::Plots.Plot{Plots.GRBackend}, ::String) at /home/joseba/.julia/packages/Plots/oiirH/src/output.jl:121
#  [8] savefig(::String) at /home/joseba/.julia/packages/Plots/oiirH/src/output.jl:123
#  [9] top-level scope at In[19]:1

# %% [markdown]
# <a href="#top">Back to the top</a>
